# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import geopandas as gp
from sklearn import linear_model
import statsmodels.api as sm
import statsmodels.formula.api as smf
# %matplotlib inline
# Out:
# /Users/Henrilin28/.pyenv/versions/2.7.8/envs/virtual_2.7/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %% [markdown]
# # Data has 311 reported homeless people for complaint type - Homeless encampment as well as homeless people reach, can the data be duplicate in both entries, our assumption is that its not!!

# %%
homeless311 = gp.read_file("../Data_vys217/DHS/homeless311_cT_1316/homeless311_ct_1316.shp")

# %%
homeless311.columns
# Out:
# Index([u'BoroCT2010',   u'BoroCode',   u'BoroName', u'CDEligibil',
#            u'CT2010',    u'CTLabel',     u'Count_',      u'FID_1',
#           u'NTACode',    u'NTAName',   u'OBJECTID',       u'PUMA',
#        u'Shape_Area', u'Shape_Le_1', u'Shape_Leng', u'Sum_Incide',
#        u'Sum_Latitu', u'Sum_Longit', u'Sum_Unique', u'Sum_X_Coor',
#        u'Sum_Y_Coor',   u'geometry'],
#       dtype='object')

# %%
homeless311.drop([u'BoroCode',   u'BoroName', u'CDEligibil',
           u'CT2010',    u'CTLabel',       u'FID_1',
          u'NTACode',    u'NTAName',   u'OBJECTID',       u'PUMA',
       u'Shape_Area', u'Shape_Le_1', u'Shape_Leng', u'Sum_Incide',
       u'Sum_Latitu', u'Sum_Longit', u'Sum_Unique', u'Sum_X_Coor',
       u'Sum_Y_Coor',   u'geometry'], axis = 1, inplace = True)

# %%
homeless311.head()
# Out:
#   BoroCT2010  Count_
# 0    5000900       8
# 1    5007400       1
# 2    1009800     112
# 3    1010000     249
# 4    1010200     365

# %%
ct = gp.read_file('../Data_vys217/nyct2010_16d/nyct2010.shp')

# %%
ct[(ct.BoroName == 'Brooklyn')]
# Out:
#      BoroCT2010 BoroCode  BoroName CDEligibil  CT2010  CTLabel NTACode  \
# 27      3000501        3  Brooklyn          I  000501     5.01    BK09
# 28      3002000        3  Brooklyn          I  002000       20    BK32
# 29      3004100        3  Brooklyn          I  004100       41    BK38
# 30      3005201        3  Brooklyn          E  005201    52.01    BK31
# 31      3005202        3  Brooklyn          I  005202    52.02    BK31
# 32      3005800        3  Brooklyn          E  005800       58    BK31
# 33      3006000        3  Brooklyn          I  006000       60    BK31
# 34      3006500        3  Brooklyn          I  006500       65    BK33
# 35      3006700        3  Brooklyn          I  006700       67    BK33
# 36      3006900        3  Brooklyn          I  006900       69    BK38
# 37      3007400        3  Brooklyn          E  007400       74    BK32
# 38      3007600        3  Brooklyn          E  007600       76    BK32
# 39      3007800        3  Brooklyn          E  007800       78    BK32
# 40      3008000        3  Brooklyn          E  008000       80    BK32
# 41      3009800        3  Brooklyn          E  009800       98    BK34
# 42      3010100        3  Brooklyn          I  010100      101    BK32
# 43      3010200        3  Brooklyn          E  010200      102    BK34
# 44      3010400        3  Brooklyn          E  010400      104    BK34
# 45      3010800        3  Brooklyn          E  010800      108    BK34
# 46      3011000        3  Brooklyn          E  011000      110    BK34
# 47      3011400        3  Brooklyn          I  011400      114    BK88
# 48      3012801        3  Brooklyn          I  012801   128.01    BK30
# 49      3013000        3  Brooklyn          E  013000      130    BK31
# 2092  10545.186560  POLYGON ((1014042.033630371 188309.223815918, ...
# 2093   5260.698117  POLYGON ((1014861.302185059 188581.5012207031,...
# 2118  15883.406088  POLYGON ((1020736.130187988 192408.3953857422,...
# 2158   5799.041459  POLYGON ((986784.2830200195 159610.2896118164,...
# 2159   7396.971075  POLYGON ((987390.5646362305 159120.7102050781,...
# 2162   5088.553511  POLYGON ((998334.9584350586 192625.3569946289,...
# 2163   5569.472441  POLYGON ((997756.6624145508 194645.1395874023,...
# 2164  15289.723553  POLYGON ((989311.0202026367 186769.067199707, ...
# 2165   5142.255127  POLYGON ((987657.6373901367 183942.375793457, ...
#
# [760 rows x 12 columns]

# %%
homeless_shelters = gp.read_file('../Data_vys217/DHS/ct_homeless_shelters.shp')

# %%
homeless_shelters.columns
# Out:
# Index([u'BoroCT2010',   u'BoroCode',   u'BoroName', u'CDEligibil',
#            u'CT2010',    u'CTLabel',     u'Count_',      u'FID_1',
#           u'NTACode',    u'NTAName',   u'OBJECTID',       u'PUMA',
#        u'Shape_Area', u'Shape_Le_1', u'Shape_Leng', u'Sum_Agen_1',
#        u'Sum_Agency',    u'Sum_BBL', u'Sum_BoroCo',     u'Sum_CD',
#        u'Sum_CapTyp', u'Sum_Capaci', u'Sum_Counci', u'Sum_FacTyp',
#        u'Sum_G9toG1', u'Sum_GroupT', u'Sum_Health', u'Sum_PKtoG8',
#        u'Sum_Police', u'Sum_SGroup', u'Sum_School', u'Sum_TaxBlo',
#        u'Sum_TaxLot', u'Sum_XCoord', u'Sum_YCoord',   u'geometry'],
#       dtype='object')

# %%
homeless_shelters
# Out:
#      BoroCT2010  Count_
# 0       5000900       0
# 1       5007400       0
# 2       1009800       2
# 3       1010000       0
# 4       1010200       0
# 5       1010400       0
# 6       1011300       0
# 7       1011402       0
# 8       1013000       0
# 9       1014000       0
# 10      1014601       0
# 11      1014602       0
# 12      1014801       0
# 13      1015300       0
# 14      1015400       0
# 15      1018400       0
# 16      1019000       0
# 17      1020102       0
# 18      1020600       1
# 19      1024900       0
# 20      1025300       0
# 21      1025700       0
# 22      1026100       1
# 23      1026300       0
# 24      1026700       0
# 25      1026900       0
# 26      1027700       0
# 27      3000501       0
# 28      3002000       0
# 29      3004100       0
# ...         ...     ...
# 2136    1017000       1
# 2137    1003400       1
# 2138    1004000       0
# 2139    1016600       1
# 2140    1017200       0
# 2141    1002000       0
# 2142    1002601       2
# 2143    1003200       0
# 2144    1003800       1
# 2145    1020300       0
# 2146    1020701       0
# 2147    1024500       0
# 2148    1024700       0
# 2149    1027500       0
# 2150    1026500       0
# 2151    1027300       0
# 2152    1016100       0
# 2153    1016500       0
# 2154    1017500       0
# 2155    1017900       0
# 2156    2006300       1
# 2157    2018900       1
# 2158    3029000       0
# 2159    3029600       0
# 2160    2002000       0
# 2161    2002400       0
# 2162    3025500       0
# 2163    3053100       0
# 2164    3011900       0
# 2165    3012100       0
#
# [2166 rows x 2 columns]

# %%
homeless_shelters.drop([ u'CDEligibil',
              u'FID_1',
          u'NTACode',    u'NTAName',   u'OBJECTID',       u'PUMA',
       u'Shape_Area', u'Shape_Le_1', u'Shape_Leng', u'Sum_Agen_1',
       u'Sum_Agency',    u'Sum_BBL', u'Sum_BoroCo',     u'Sum_CD',
       u'Sum_CapTyp', u'Sum_Capaci', u'Sum_Counci', u'Sum_FacTyp',
       u'Sum_G9toG1', u'Sum_GroupT', u'Sum_Health', u'Sum_PKtoG8',
       u'Sum_Police', u'Sum_SGroup', u'Sum_School', u'Sum_TaxBlo',
       u'Sum_TaxLot', u'Sum_XCoord', u'Sum_YCoord',   u'geometry'], axis = 1, inplace = True)

# %%
homeless_shelters.drop(['BoroCode','BoroName','CT2010','CTLabel'], axis= 1, inplace=True)

# %%
homeless_shelters.head(2)
# Out:
#   BoroCT2010  Count_
# 0    5000900       0
# 1    5007400       0

# %%
demographics =pd.read_csv('../Data_vys217/demographics_data2go.csv', 
                          usecols= ['BoroCT','adult_samehome_tract', 'aframer_pop_tract', 'asian_api_pop_tract',
                                    'foreign_tract', 'disabled_tract', 'divorced_tract', 'latino_pop_tract',
                                   'natamer_pop_tract', 'no_hs_tract','ex_high_cost_h_tract', 'labor_force_participation_tract',
                                    'median_household_income_tract','poverty_all_ages_federal_percent_tract', 'unemployment_tract',
                                    'unpaid_family_workers_class_tract', 'working_poor_tract'])

# %%
demographics.rename(columns={'BoroCT':'BoroCT2010'}, inplace=True)

# %%
demographics.BoroCT2010 = demographics.BoroCT2010.astype('unicode')

# %%
len(demographics.BoroCT2010.unique())
# Out:
# 2166

# %%
len(homeless_shelters.BoroCT2010.unique())
# Out:
# 2166

# %%
len(crime_ct.BoroCT2010.unique())
# Out:
# 2166

# %%
demographics.head(2)
# Out:
#    BoroCT2010  adult_samehome_tract  aframer_pop_tract  asian_api_pop_tract  \
# 0     2003300              94.43787          29.231568             0.000000
# 1     2003900              88.45986          18.449848             1.170213
#
#    disabled_tract  divorced_tract  foreign_tract  latino_pop_tract  \
# 0       15.420561        5.244123      28.712357         70.145379
# 1       17.090632        4.010025      36.762918         78.282675
#
#    natamer_pop_tract  no_hs_tract  ex_high_cost_h_tract  \
# 0                0.0    43.799719             30.622010
# 1                0.0    38.703089             35.369239
#
#    labor_force_participation_tract  median_household_income_tract  \
# 0                        49.535834                        19784.0
# 1                        61.900703                        27608.0
#
#    poverty_all_ages_federal_percent_tract  unemployment_tract  \
# 0                                    49.1            9.097661
# 1                                    29.7            7.180908
#
#    unpaid_family_workers_class_tract  working_poor_tract
# 0                                0.0           29.109275
# 1                                0.3           10.942368

# %%
demographics[demographics.BoroCT2010 == 1009800]
# Out:
#       BoroCT2010  adult_samehome_tract  aframer_pop_tract  \
# 1197     1009800             88.050222           1.631412
# 1454     1009800             89.598540          14.042405
#
#       asian_api_pop_tract  disabled_tract  divorced_tract  foreign_tract  \
# 1197            13.466058        9.305228        5.704599      22.397346
# 1454            32.603406        7.646854        6.393089      68.057004
#
#       latino_pop_tract  natamer_pop_tract  no_hs_tract  ex_high_cost_h_tract  \
# 1197          6.262961           0.000000     2.704945             16.190849
# 1454         14.355231           1.529371    22.765073             37.560976
#
#       labor_force_participation_tract  median_household_income_tract  \
# 1197                        74.351415                       110735.0
# 1454                        67.571116                        63796.0
#
#       poverty_all_ages_federal_percent_tract  unemployment_tract  \
# 1197                                     4.5            2.078420
# 1454                                    22.9           11.466083
#
#       unpaid_family_workers_class_tract  working_poor_tract
# 1197                                0.0            0.614628
# 1454                                0.0            9.828393

# %%
crime_ct = gp.read_file('../Data_vys217/Crime/crimes_ct/crime_ct.shp')

# %%
crime_ct.columns
# Out:
# Index([u'BoroCT2010',   u'BoroCode',   u'BoroName', u'CDEligibil',
#            u'CT2010',    u'CTLabel',     u'Count_',      u'FID_1',
#           u'NTACode',    u'NTAName',   u'OBJECTID',       u'PUMA',
#        u'Shape_Area', u'Shape_Le_1', u'Shape_Leng', u'Sum_CMPLNT',
#        u'Sum_Latitu', u'Sum_Longit',   u'geometry'],
#       dtype='object')

# %%
crime_ct.drop([u'BoroCode',   u'BoroName', u'CDEligibil',
           u'CT2010',    u'CTLabel',        u'FID_1',
          u'NTACode',    u'NTAName',   u'OBJECTID',       u'PUMA',
       u'Shape_Area', u'Shape_Le_1', u'Shape_Leng', u'Sum_CMPLNT',
       u'Sum_Latitu', u'Sum_Longit',   u'geometry'], axis = 1, inplace =True)

# %%
crime_ct.rename(columns={'Count_':'Crime'}, inplace=True)

# %%
homeless_regress = pd.DataFrame()

# %%
homeless_regress = pd.merge(crime_ct,homeless_shelters, how='inner', on='BoroCT2010')

# %%
homeless_regress = pd.merge(homeless311,homeless_regress, how='inner', on='BoroCT2010')

# %%
homeless_regress.columns = ['BoroCT2010','homeless311_comp', 'Crime', 'homeless_shelters']

# %%
homeless_regress = pd.merge(homeless_regress,demographics, how='inner', on='BoroCT2010')

# %%
homeless_regress
# Out:
#     BoroCT2010  homeless311_comp  Crime  homeless_shelters  \
# 0      5000900                 8    129                  0
# 1      5007400                 1    124                  0
# 2      1009800               112    217                  2
# 3      1010000               249    361                  0
# 4      1010200               365    177                  0
# 5      1010400               491    456                  0
# 6      1011300              1072    372                  0
# 7      1011402               175    432                  0
# 8      1013000                63     60                  0
# 9      1014000                57    200                  0
# 10     1014601                46     76                  0
# 11     1014602                91    131                  0
# 12     1014801               330     93                  0
# 13     1015300               548    338                  0
# 14     1015400                46    221                  0
# 15     1018400                97    393                  0
# 16     1019000                20    361                  0
# 17     1020102               214    258                  0
# 18     1020600               110    244                  1
# 19     1024900                 3    178                  0
# 20     1025300                62    303                  0
# 21     1025700               160    402                  0
# 22     1026100                20    361                  1
# 23     1026300                17    326                  0
# 24     1026700                 3     26                  0
# 25     1026900                29    335                  0
# 26     1027700                 8    197                  0
# 27     2003300                 2    213                  1
# 28     2007000                 4    224                  0
# 29     2012500                 7    255                  0
# ..         ...               ...    ...                ...
# 541    1001401                12     51                  0
# 542    1028100                 9     31                  0
# 543    1014300               129    505                  0
# 544    1018900                71    582                  0
# 545    1019701               253    123                  0
# 546    1020101                38     23                  0
# 547    1014802               188    507                  0
# 548    1015801                31    129                  0
# 570                                    13.9            4.034291
#
#      unpaid_family_workers_class_tract  working_poor_tract
# 0                                  0.5            3.836634
# 1                                  0.0            5.669145
# 2                                  0.0            0.614628
# 3                                  0.0            6.204674
# 4                                  0.0            0.000000
# 5                                  0.0            2.811951
# 6                                  0.0            2.061856
# 7                                  1.1            2.045827
# 8                                  2.2            4.394299
# 9                                  0.0            3.351206
# 10                                 0.0            2.750860
# 11                                 0.4            2.522491
# 12                                 0.0            1.002950
# 13                                 0.0            2.205735
# 14                                 0.0            1.954755
# 15                                 0.0           15.524476
# 16                                 0.0            6.626506
# 17                                 0.0            7.225310
# 18                                 0.0           10.478360
# 19                                 0.0            5.251142
# 20                                 0.4           11.596919
# 21                                 0.0            3.152279
# 22                                 0.0           16.688808
# 23                                 0.0           17.772675
# 24                                 0.8           12.342569
# 25                                 0.0           12.188491
# 26                                 0.0           19.309838
# 27                                 0.0           29.109275
# 28                                 0.0           10.016788
# 29                                 1.8           16.109874
# ..                                 ...                 ...
# 541                                1.0            2.173913
# 542                                0.0            1.242604
# 543                                NaN                 NaN
# 544                                0.0           13.363854
# 545                                0.0            8.188586
# 546                                0.0            3.971119
# 547                                0.3            3.592672
# 548                                0.0            3.287944
# 549                                0.0            3.257437
# 550                                0.2            6.038593
# 551                                0.2           15.389487
# 552                                0.3           10.633633
# 553                                0.0            4.591922
# 554                                0.0           10.815648
# 555                                1.9           11.111111
# 556                                0.0           20.111732
# 557                                0.0            8.972504
# 558                                0.0            2.139037
# 559                                0.0            4.085078
# 560                                0.0           14.974182
# 561                                0.0            5.427509
# 562                                0.3           20.783476
# 563                                0.7            7.708953
# 564                                0.5            1.061008
# 565                                0.0            9.308642
# 566                                0.0            9.527478
# 567                                0.0            1.887221
# 568                                0.0            2.163103
# 569                                0.0            1.220980
# 570                                0.0            4.830918
#
# [571 rows x 20 columns]

# %%
plt.plot((homeless_regress.divorced_tract),(homeless_regress.homeless311_comp),'o')
plt.xlabel('Crime Counts in NYC')
plt.ylabel('311 Homeless complaints')

# %%
X = homeless_regress.iloc[:,2:]

# %%
y = homeless_regress.iloc[:,1]

# %%
lm = sm.OLS(y,X)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-220-d5a446d51431> in <module>()
# ----> 1 lm = sm.OLS(y,X)
#
# C:\Users\Vishwajeet\Anaconda2\lib\site-packages\statsmodels\regression\linear_model.pyc in __init__(self, endog, exog, missing, hasconst, **kwargs)
#     689                  **kwargs):
#     690         super(OLS, self).__init__(endog, exog, missing=missing,
# --> 691                                   hasconst=hasconst, **kwargs)
#     692         if "weights" in self._init_keys:
#     693             self._init_keys.remove("weights")
#
# C:\Users\Vishwajeet\Anaconda2\lib\site-packages\statsmodels\regression\linear_model.pyc in __init__(self, endog, exog, weights, missing, hasconst, **kwargs)
#     584             weights = weights.squeeze()
#     585         super(WLS, self).__init__(endog, exog, missing=missing,
# --> 586                                   weights=weights, hasconst=hasconst, **kwargs)
#     587         nobs = self.exog.shape[0]
#     588         weights = self.weights
#
# C:\Users\Vishwajeet\Anaconda2\lib\site-packages\statsmodels\regression\linear_model.pyc in __init__(self, endog, exog, **kwargs)
#      89     """
#      90     def __init__(self, endog, exog, **kwargs):
# ---> 91         super(RegressionModel, self).__init__(endog, exog, **kwargs)
#      92         self._data_attr.extend(['pinv_wexog', 'wendog', 'wexog', 'weights'])
#      93
#
# C:\Users\Vishwajeet\Anaconda2\lib\site-packages\statsmodels\base\model.pyc in __init__(self, endog, exog, **kwargs)
#     184
#     185     def __init__(self, endog, exog=None, **kwargs):
# --> 186         super(LikelihoodModel, self).__init__(endog, exog, **kwargs)
#     187         self.initialize()
#     188
#
# C:\Users\Vishwajeet\Anaconda2\lib\site-packages\statsmodels\base\model.pyc in __init__(self, endog, exog, **kwargs)
#      58         hasconst = kwargs.pop('hasconst', None)
#      59         self.data = self._handle_data(endog, exog, missing, hasconst,
# ---> 60                                       **kwargs)
#      61         self.k_constant = self.data.k_constant
#      62         self.exog = self.data.exog
#
# C:\Users\Vishwajeet\Anaconda2\lib\site-packages\statsmodels\base\model.pyc in _handle_data(self, endog, exog, missing, hasconst, **kwargs)
#      82
#      83     def _handle_data(self, endog, exog, missing, hasconst, **kwargs):
# ---> 84         data = handle_data(endog, exog, missing, hasconst, **kwargs)
#      85         # kwargs arrays could have changed, easier to just attach here
#      86         for key in kwargs:
#
# C:\Users\Vishwajeet\Anaconda2\lib\site-packages\statsmodels\base\data.pyc in handle_data(endog, exog, missing, hasconst, **kwargs)
#     564     klass = handle_data_class_factory(endog, exog)
#     565     return klass(endog, exog=exog, missing=missing, hasconst=hasconst,
# --> 566                  **kwargs)
#
# C:\Users\Vishwajeet\Anaconda2\lib\site-packages\statsmodels\base\data.pyc in __init__(self, endog, exog, missing, hasconst, **kwargs)
#      73
#      74         # this has side-effects, attaches k_constant and const_idx
# ---> 75         self._handle_constant(hasconst)
#      76         self._check_integrity()
#      77         self._cache = resettable_cache()
#
# C:\Users\Vishwajeet\Anaconda2\lib\site-packages\statsmodels\base\data.pyc in _handle_constant(self, hasconst)
#     132                 augmented_exog = np.column_stack(
#     133                             (np.ones(self.exog.shape[0]), self.exog))
# --> 134                 rank_augm = np_matrix_rank(augmented_exog)
#     135                 rank_orig = np_matrix_rank(self.exog)
#     136                 self.k_constant = int(rank_orig == rank_augm)
#
# C:\Users\Vishwajeet\Anaconda2\lib\site-packages\numpy\linalg\linalg.pyc in matrix_rank(M, tol)
#    1541     if M.ndim < 2:
#    1542         return int(not all(M==0))
# -> 1543     S = svd(M, compute_uv=False)
#    1544     if tol is None:
#    1545         tol = S.max() * max(M.shape) * finfo(S.dtype).eps
#
# C:\Users\Vishwajeet\Anaconda2\lib\site-packages\numpy\linalg\linalg.pyc in svd(a, full_matrices, compute_uv)
#    1369
#    1370         signature = 'D->d' if isComplexType(t) else 'd->d'
# -> 1371         s = gufunc(a, signature=signature, extobj=extobj)
#    1372         s = s.astype(_realType(result_t), copy=False)
#    1373         return s
#
# ValueError: On entry to DLASCL parameter number 5 had an illegal value

# %%
lm = smf.ols(formula = 'homeless311_comp ~ divorced_tract - 1',
             data = homeless_regress).fit()

# %%
print lm.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       homeless311_comp   R-squared:                       0.176
# Model:                            OLS   Adj. R-squared:                  0.174
# Method:                 Least Squares   F-statistic:                     119.0
# Date:                Fri, 09 Dec 2016   Prob (F-statistic):           3.02e-25
# Time:                        11:17:55   Log-Likelihood:                -3710.1
# No. Observations:                 559   AIC:                             7422.
# Df Residuals:                     558   BIC:                             7427.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------
# divorced_tract     8.8461      0.811     10.909      0.000         7.253    10.439
# ==============================================================================
# Omnibus:                      289.532   Durbin-Watson:                   1.302
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1906.739
# Skew:                           2.233   Prob(JB):                         0.00
# Kurtosis:                      10.869   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
homeless2016 = pd.read_csv("../Data_vys217/DHS/311_Service_Requests/311_Service_Requests_from_2016.csv",
                           usecols=['Created Date', 'Incident Zip'])

# %%
homeless2015new = pd.read_csv("../Data_vys217/DHS/311_Service_Requests/311_Service_Requests_from_2015_nyc_filter.csv",
                               usecols=['Created Date', 'Incident Zip'])

# %%
homeless2016['Created Date'] = pd.to_datetime(homeless2016['Created Date'])
homeless2015new['Created Date'] = pd.to_datetime(homeless2015new['Created Date'])

# %%
homeless2015new.head()
# Out:
#          Created Date  Incident Zip
# 0 2015-06-03 09:38:31       10009.0
# 1 2015-06-30 08:03:05       10001.0
# 2 2015-08-02 08:41:08       10009.0
# 3 2015-11-29 12:38:41       10009.0
# 4 2015-03-31 08:07:24       10019.0

# %%
homeless2015new['Created Date'].describe()
# Out:
# count                   11318
# unique                  11317
# top       2015-05-04 21:55:20
# freq                        2
# first     2015-01-01 04:29:10
# last      2015-12-30 21:11:49
# Name: Created Date, dtype: object

# %%
homeless2016['Created Date'].describe()
# Out:
# count                   47678
# unique                  47561
# top       2016-08-06 08:31:48
# freq                        3
# first     2016-01-01 02:26:46
# last      2016-11-29 01:47:42
# Name: Created Date, dtype: object

# %% [markdown]
# # Number of reported homeless people on streets has increased 4 times in 2016 from 2015

# %%
homeless2015new.drop(['Created Date'], axis=1, inplace=True)
homeless2016.drop(['Created Date'], axis=1, inplace=True)

# %%
print homeless2015new.shape
print homeless2016.shape
# Out:
# (11318, 1)
# (47678, 1)

# %%
homeless2015new.dropna(inplace=True)
homeless2016.dropna(inplace=True)

# %%
print homeless2015new.shape
print homeless2016.shape
# Out:
# (11101, 1)
# (46837, 1)

# %%
#Merge 2015 and 16 data
homeless15_16 = pd.concat([homeless2015new, homeless2016], ignore_index= True)

# %%
homless_counts = homeless15_16['Incident Zip'].value_counts()

# %%
homless_counts = pd.DataFrame(homless_counts)

# %%
homless_counts.reset_index(inplace=True)

# %%
homless_counts.columns
# Out:
# Index([u'index', u'Incident Zip'], dtype='object')

# %%
homless_counts.rename(columns={'index':'zip_code', 'Incident Zip':'homeless_count'}, inplace=True)

# %%
homless_counts.head()
# Out:
#    zip_code  homeless_count
# 0   10003.0            4367
# 1   10036.0            3507
# 2   10001.0            3462
# 3   10023.0            3311
# 4   10019.0            3004

# %%
homless_counts.homeless_count.hist(bins=1000)

# %% [markdown]
# # Get the crimes count data

# %%
crimes_counts = pd.read_csv("C:\Users\Vishwajeet\Documents\Python Scripts\Homeless\VYS217\Data_vys217\Crime\intermittent\crimes_counts.csv")

# %%
crimes_counts.drop(['Unnamed: 0'], axis= 1, inplace= True)

# %%
crimes_counts.
# Out:
#    zip_code  crime_count
# 0     10001         4404
# 1     10002         4145
# 2     10003         3397
# 3     10004          453
# 4     10005          285

# %% [markdown]
# # Merge the homeless and crime data

# %%
homeless_crimes = pd.merge(crimes_counts, homless_counts, on='zip_code', how='inner')

# %%
homeless_crimes = homeless_crimes[homeless_crimes.zip_code > 10000]

# %%
homeless_crimes
# Out:
#      zip_code  crime_count  homeless_count
# 0       10001         4404            3462
# 1       10002         4145             692
# 2       10003         3397            4367
# 3       10004          453             294
# 4       10005          285             341
# 5       10006          242             167
# 6       10007          985             361
# 7       10009         2408            1442
# 8       10010         1530             992
# 9       10011         3185            2744
# 10      10012         1959            1500
# 11      10013         2262            1002
# 12      10014         1699             884
# 13      10016         1748            2422
# 14      10017         1165            1738
# 15      10018         1969            1841
# 16      10019         3360            3004
# 17      10020          312              51
# 18      10021          699             570
# 19      10022         1750            1344
# 20      10023         2098            3311
# 21      10024         1546            1570
# 22      10025         3156            1813
# 23      10026         2661             690
# 24      10027         4677            1126
# 25      10028         1038             724
# 26      10029         5015             559
# 27      10030         1918             162
# 28      10031         2909             498
# 29      10032         2411             171
# ..        ...          ...             ...
# 183     11379          664              25
# 184     11385         3049             129
# 185     11411          557              16
# 186     11412         1240              23
# 187     11413         1402              28
# 188     11414          609              36
# 189     11415          426              51
# 190     11416          839              32
# 191     11417         1122              42
# 192     11418         1319              88
# 193     11419         1601              27
# 194     11420         1667              27
# 195     11421          929              23
# 196     11422          806              12
# 197     11423          910              49
# 198     11426          377               3
# 199     11427          546              14
# 200     11428          565              19
# 201     11429          856              23
# 202     11430           19               8
# 203     11432         2650             178
# 204     11433         2057              80
# 205     11434         3883              47
# 206     11435         1851             138
# 207     11436          635              23
# 208     11691         3193              53
# 209     11692          921               8
# 210     11693          864              14
# 211     11694          623              16
# 212     11697           94               3
#
# [213 rows x 3 columns]

# %% [markdown]
# # Pearson's correlation coefficient function of pandas

# %%
homeless_crimes.corr()
# Out:
#                 zip_code  crime_count  homeless_count
# zip_code        1.000000     0.073128       -0.358332
# crime_count     0.073128     1.000000        0.286863
# homeless_count -0.358332     0.286863        1.000000

# %%
plt.plot(np.log10(homeless_crimes.crime_count),np.log10(homeless_crimes.homeless_count),'o')
plt.xlabel('Crime Counts in NYC')
plt.ylabel('311 Homeless complaints')

# %%
homeless_crime_log =pd.DataFrame()
homeless_crime_log['log_homeless'] = np.log10(homeless_crimes.homeless_count)
homeless_crime_log['log_crimes'] = np.log10(homeless_crimes.crime_count)
homeless_crime_log['log_crimes_2'] = (np.log10(homeless_crimes.crime_count))**2

# %% [markdown]
# # Pearson's correlation coefficient function of pandas for log data

# %%
homeless_crime_log.corr()
# Out:
#               log_homeless  log_crimes  log_crimes_2
# log_homeless      1.000000    0.626110      0.633303
# log_crimes        0.626110    1.000000      0.982467
# log_crimes_2      0.633303    0.982467      1.000000

# %%
lm = smf.ols(formula= 'log_homeless ~ log_crimes', data= homeless_crime_log).fit()
print lm.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           log_homeless   R-squared:                         nan
# Model:                            OLS   Adj. R-squared:                    nan
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Fri, 02 Dec 2016   Prob (F-statistic):                nan
# Time:                        15:31:47   Log-Likelihood:                    nan
# No. Observations:                 213   AIC:                               nan
# Df Residuals:                     213   BIC:                               nan
# Df Model:                          -1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept         nan        nan        nan        nan           nan       nan
# log_crimes        nan        nan        nan        nan           nan       nan
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                     nan
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                  nan
# Skew:                             nan   Prob(JB):                          nan
# Kurtosis:                         nan   Cond. No.                          nan
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
