# %%
from __future__ import print_function
import numpy as np
from scipy import stats
import pandas as pd
import matplotlib.pyplot as pl

import statsmodels.api as sm

from statsmodels.graphics.api import qqplot

# %pylab inline
import matplotlib
matplotlib.style.use('ggplot')
# %matplotlib inline
data = pd.read_excel("NYCHomelessShelterPopulation-Worksheet1983-Present_Oct2016.xlsx")
data = data[["Time","Adults in Families"]]
data.dropna(axis=0,inplace=True)
data["Time"] = data["Time"].apply(lambda x: pd.to_datetime(x))
from matplotlib.dates import YearLocator, MonthLocator, DateFormatter
import datetime
years = YearLocator()   # every year
months = MonthLocator()  # every month
yearsFmt = DateFormatter('%Y')
monthsFmt = DateFormatter('%m')
ax = pl.figure(figsize = (15,8)).gca()
ax.plot(data["Time"], data["Adults in Families"])
pl.xlabel('Time', fontsize=15)
pl.ylabel('Adults in Families in Shelters', fontsize=15)
pl.title("NEW YORK CITY HOMELESS MUNICIPAL SHELTER POPULATION, Since 1983", fontsize=15)
#pl.grid()
ax.xaxis.set_major_locator(years)
ax.xaxis.set_major_formatter(yearsFmt)
# ax.xaxis.set_minor_locator(months)
# ax.xaxis.set_minor_formatter(monthsFmt)
pl.xticks(rotation = 75, fontsize = 15)
pl.yticks(fontsize = 15)
pl.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
